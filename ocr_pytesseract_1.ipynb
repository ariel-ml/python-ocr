# %%
# %pip install -q easyocr

# %%
# import easyocr
import pytesseract
import cv2
import utils

# %%
img = cv2.imread("assets/dilated.jpg")

# %%
utils.display(img)

# %%
print(pytesseract.image_to_string(img))
# Out:
# Szuletesi hely/Place of birth:
#
# TATABANYA (MAGYARORSZAG) ets:
# fr]
# Szuletési csaladi és utonév/Family name and Given name at birth: :
# BERKI DORA
# Anyja siletési neve/ Mother's maiden name: 973940AE
# DR. SOMHEGY! ANTONIA
#
# Kiallito hatésag//ssuing authority: KEKKH 2016.09.24
#
# I<HUNOT39O4OAEK4 KKK KKK KKK KKK
# 7710023 F2209243HUNK<K <<< <<< <<< <G
# KOEVERNE<XBERKI<<DORA<<<<<<<<<<
